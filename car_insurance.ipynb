# %% [markdown]
# ##Data Gathering##

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/insurance_claims.csv')

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %% [markdown]
# ##Data Preparation##

# %%
df._c39
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 995   NaN
# 996   NaN
# 997   NaN
# 998   NaN
# 999   NaN
# Name: _c39, Length: 1000, dtype: float64

# %%
df.drop(columns=['_c39'],inplace=True)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0         466132  ...         2                     YES              71610
# 1         468176  ...         0                       ?               5070
# 2         430632  ...         3                      NO              34650
# 3         608117  ...         2                      NO              63400
# 4         610706  ...         1                      NO               6500
# ..           ...  ...       ...                     ...                ...
# 995       431289  ...         1                       ?              87200
# 996       608177  ...         3                       ?             108480
# 997       442797  ...         3                     YES              67500
# 998       441714  ...         1                     YES              46980
# 999       612260  ...         3                       ?               5060
#
#     injury_claim property_claim  vehicle_claim   auto_make auto_model  \
# 0           6510          13020          52080        Saab        92x
# 1            780            780           3510    Mercedes       E400
# 2           7700           3850          23100       Dodge        RAM
# 3           6340           6340          50720   Chevrolet      Tahoe
# 4           1300            650           4550      Accura        RSX
# ..           ...            ...            ...         ...        ...
# 995        17440           8720          61040       Honda     Accord
# 996        18080          18080          72320  Volkswagen     Passat
# 997         7500           7500          52500      Suburu    Impreza
# 998         5220           5220          36540        Audi         A5
# 999          460            920           3680    Mercedes       E400
#
#     auto_year fraud_reported
# 0        2004              Y
# 1        2007              Y
# 2        2007              N
# 3        2014              Y
# 4        2009              N
# ..        ...            ...
# 995      2006              N
# 996      2015              N
# 997      1996              N
# 998      1998              N
# 999      2007              N
#
# [1000 rows x 39 columns]

# %%
df.drop(columns=['policy_number'],inplace=True)

# %%
df
# Out:
#      months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                   328   48       2014-10-17           OH    250/500
# 1                   228   42       2006-06-27           IN    250/500
# 2                   134   29       2000-09-06           OH    100/300
# 3                   256   41       1990-05-25           IL    250/500
# 4                   228   44       2014-06-06           IL   500/1000
# ..                  ...  ...              ...          ...        ...
# 995                   3   38       1991-07-16           OH   500/1000
# 996                 285   41       2014-01-05           IL    100/300
# 997                 130   34       2003-02-17           OH    250/500
# 998                 458   62       2011-11-18           IL   500/1000
# 999                 456   60       1996-11-11           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1406.91               0       466132
# 1                 2000                1197.22         5000000       468176
# 2                 2000                1413.14         5000000       430632
# 3                 2000                1415.74         6000000       608117
# 4                 1000                1583.91         6000000       610706
# ..                 ...                    ...             ...          ...
# 995               1000                1310.80               0       431289
# 996               1000                1436.79               0       608177
# 997                500                1383.49         3000000       442797
# 998               2000                1356.92         5000000       441714
# 999               1000                 766.19               0       612260
#
#     insured_sex  ... witnesses police_report_available total_claim_amount  \
# 0          MALE  ...         2                     YES              71610
# 1          MALE  ...         0                       ?               5070
# 2        FEMALE  ...         3                      NO              34650
# 3        FEMALE  ...         2                      NO              63400
# 4          MALE  ...         1                      NO               6500
# ..          ...  ...       ...                     ...                ...
# 995      FEMALE  ...         1                       ?              87200
# 996      FEMALE  ...         3                       ?             108480
# 997      FEMALE  ...         3                     YES              67500
# 998        MALE  ...         1                     YES              46980
# 999      FEMALE  ...         3                       ?               5060
#
#     injury_claim  property_claim  vehicle_claim   auto_make auto_model  \
# 0           6510           13020          52080        Saab        92x
# 1            780             780           3510    Mercedes       E400
# 2           7700            3850          23100       Dodge        RAM
# 3           6340            6340          50720   Chevrolet      Tahoe
# 4           1300             650           4550      Accura        RSX
# ..           ...             ...            ...         ...        ...
# 995        17440            8720          61040       Honda     Accord
# 996        18080           18080          72320  Volkswagen     Passat
# 997         7500            7500          52500      Suburu    Impreza
# 998         5220            5220          36540        Audi         A5
# 999          460             920           3680    Mercedes       E400
#
#     auto_year fraud_reported
# 0        2004              Y
# 1        2007              Y
# 2        2007              N
# 3        2014              Y
# 4        2009              N
# ..        ...            ...
# 995      2006              N
# 996      2015              N
# 997      1996              N
# 998      1998              N
# 999      2007              N
#
# [1000 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_bind_date', 'policy_state',
#        'policy_csl', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_location               object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# bodily_injuries                  int64
# witnesses                        int64
# police_report_available         object
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_make                       object
# auto_model                      object
# auto_year                        int64
# fraud_reported                  object
# dtype: object

# %%
df.incident_date = pd.to_datetime(df.incident_date)

# %%
df.dtypes
# Out:
# months_as_customer                      int64
# age                                     int64
# policy_bind_date                       object
# policy_state                           object
# policy_csl                             object
# policy_deductable                       int64
# policy_annual_premium                 float64
# umbrella_limit                          int64
# insured_zip                             int64
# insured_sex                            object
# insured_education_level                object
# insured_occupation                     object
# insured_hobbies                        object
# insured_relationship                   object
# capital-gains                           int64
# capital-loss                            int64
# incident_date                  datetime64[ns]
# incident_type                          object
# collision_type                         object
# incident_severity                      object
# authorities_contacted                  object
# incident_state                         object
# incident_city                          object
# incident_location                      object
# incident_hour_of_the_day                int64
# number_of_vehicles_involved             int64
# property_damage                        object
# bodily_injuries                         int64
# witnesses                               int64
# police_report_available                object
# total_claim_amount                      int64
# injury_claim                            int64
# property_claim                          int64
# vehicle_claim                           int64
# auto_make                              object
# auto_model                             object
# auto_year                               int64
# fraud_reported                         object
# dtype: object

# %%
df.policy_bind_date = pd.to_datetime(df.policy_bind_date)

# %%
df.dtypes
# Out:
# months_as_customer                      int64
# age                                     int64
# policy_bind_date               datetime64[ns]
# policy_state                           object
# policy_csl                             object
# policy_deductable                       int64
# policy_annual_premium                 float64
# umbrella_limit                          int64
# insured_zip                             int64
# insured_sex                            object
# insured_education_level                object
# insured_occupation                     object
# insured_hobbies                        object
# insured_relationship                   object
# capital-gains                           int64
# capital-loss                            int64
# incident_date                  datetime64[ns]
# incident_type                          object
# collision_type                         object
# incident_severity                      object
# authorities_contacted                  object
# incident_state                         object
# incident_city                          object
# incident_location                      object
# incident_hour_of_the_day                int64
# number_of_vehicles_involved             int64
# property_damage                        object
# bodily_injuries                         int64
# witnesses                               int64
# police_report_available                object
# total_claim_amount                      int64
# injury_claim                            int64
# property_claim                          int64
# vehicle_claim                           int64
# auto_make                              object
# auto_model                             object
# auto_year                               int64
# fraud_reported                         object
# dtype: object

# %%
import numpy as np

# %%
import numpy as np

# Calculate the difference in days
df['days_bw_incident_and_bind'] = (df.incident_date - df.policy_bind_date).dt.days

# Approximate months by dividing days by the average days per month
df['months_bw_incident_and_bind'] = df['days_bw_incident_and_bind'] / 30

# %%
df
# Out:
#      months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                   328   48       2014-10-17           OH    250/500
# 1                   228   42       2006-06-27           IN    250/500
# 2                   134   29       2000-09-06           OH    100/300
# 3                   256   41       1990-05-25           IL    250/500
# 4                   228   44       2014-06-06           IL   500/1000
# ..                  ...  ...              ...          ...        ...
# 995                   3   38       1991-07-16           OH   500/1000
# 996                 285   41       2014-01-05           IL    100/300
# 997                 130   34       2003-02-17           OH    250/500
# 998                 458   62       2011-11-18           IL   500/1000
# 999                 456   60       1996-11-11           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1406.91               0       466132
# 1                 2000                1197.22         5000000       468176
# 2                 2000                1413.14         5000000       430632
# 3                 2000                1415.74         6000000       608117
# 4                 1000                1583.91         6000000       610706
# ..                 ...                    ...             ...          ...
# 995               1000                1310.80               0       431289
# 996               1000                1436.79               0       608177
# 997                500                1383.49         3000000       442797
# 998               2000                1356.92         5000000       441714
# 999               1000                 766.19               0       612260
#
#     insured_sex  ... total_claim_amount injury_claim property_claim  \
# 0          MALE  ...              71610         6510          13020
# 1          MALE  ...               5070          780            780
# 2        FEMALE  ...              34650         7700           3850
# 3        FEMALE  ...              63400         6340           6340
# 4          MALE  ...               6500         1300            650
# ..          ...  ...                ...          ...            ...
# 995      FEMALE  ...              87200        17440           8720
# 996      FEMALE  ...             108480        18080          18080
# 997      FEMALE  ...              67500         7500           7500
# 998        MALE  ...              46980         5220           5220
# 999      FEMALE  ...               5060          460            920
#
#     vehicle_claim   auto_make  auto_model auto_year fraud_reported  \
# 0           52080        Saab         92x      2004              Y
# 1            3510    Mercedes        E400      2007              Y
# 2           23100       Dodge         RAM      2007              N
# 3           50720   Chevrolet       Tahoe      2014              Y
# 4            4550      Accura         RSX      2009              N
# ..            ...         ...         ...       ...            ...
# 995         61040       Honda      Accord      2006              N
# 996         72320  Volkswagen      Passat      2015              N
# 997         52500      Suburu     Impreza      1996              N
# 998         36540        Audi          A5      1998              N
# 999          3680    Mercedes        E400      2007              N
#
#     days_bw_incident_and_bind months_bw_incident_and_bind
# 0                         100                    3.333333
# 1                        3130                  104.333333
# 2                        5282                  176.066667
# 3                        8996                  299.866667
# 4                         256                    8.533333
# ..                        ...                         ...
# 995                      8622                  287.400000
# 996                       384                   12.800000
# 997                      4358                  145.266667
# 998                      1196                   39.866667
# 999                      6681                  222.700000
#
# [1000 rows x 40 columns]

# %%
df.drop(columns=['days_bw_incident_and_bind'],inplace=True)

# %%
df
# Out:
#      months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                   328   48       2014-10-17           OH    250/500
# 1                   228   42       2006-06-27           IN    250/500
# 2                   134   29       2000-09-06           OH    100/300
# 3                   256   41       1990-05-25           IL    250/500
# 4                   228   44       2014-06-06           IL   500/1000
# ..                  ...  ...              ...          ...        ...
# 995                   3   38       1991-07-16           OH   500/1000
# 996                 285   41       2014-01-05           IL    100/300
# 997                 130   34       2003-02-17           OH    250/500
# 998                 458   62       2011-11-18           IL   500/1000
# 999                 456   60       1996-11-11           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1406.91               0       466132
# 1                 2000                1197.22         5000000       468176
# 2                 2000                1413.14         5000000       430632
# 3                 2000                1415.74         6000000       608117
# 4                 1000                1583.91         6000000       610706
# ..                 ...                    ...             ...          ...
# 995               1000                1310.80               0       431289
# 996               1000                1436.79               0       608177
# 997                500                1383.49         3000000       442797
# 998               2000                1356.92         5000000       441714
# 999               1000                 766.19               0       612260
#
#     insured_sex  ... police_report_available total_claim_amount injury_claim  \
# 0          MALE  ...                     YES              71610         6510
# 1          MALE  ...                       ?               5070          780
# 2        FEMALE  ...                      NO              34650         7700
# 3        FEMALE  ...                      NO              63400         6340
# 4          MALE  ...                      NO               6500         1300
# ..          ...  ...                     ...                ...          ...
# 995      FEMALE  ...                       ?              87200        17440
# 996      FEMALE  ...                       ?             108480        18080
# 997      FEMALE  ...                     YES              67500         7500
# 998        MALE  ...                     YES              46980         5220
# 999      FEMALE  ...                       ?               5060          460
#
#     property_claim  vehicle_claim   auto_make auto_model auto_year  \
# 0            13020          52080        Saab        92x      2004
# 1              780           3510    Mercedes       E400      2007
# 2             3850          23100       Dodge        RAM      2007
# 3             6340          50720   Chevrolet      Tahoe      2014
# 4              650           4550      Accura        RSX      2009
# ..             ...            ...         ...        ...       ...
# 995           8720          61040       Honda     Accord      2006
# 996          18080          72320  Volkswagen     Passat      2015
# 997           7500          52500      Suburu    Impreza      1996
# 998           5220          36540        Audi         A5      1998
# 999            920           3680    Mercedes       E400      2007
#
#     fraud_reported months_bw_incident_and_bind
# 0                Y                    3.333333
# 1                Y                  104.333333
# 2                N                  176.066667
# 3                Y                  299.866667
# 4                N                    8.533333
# ..             ...                         ...
# 995              N                  287.400000
# 996              N                   12.800000
# 997              N                  145.266667
# 998              N                   39.866667
# 999              N                  222.700000
#
# [1000 rows x 39 columns]

# %%
df['incident_within_customership'] = df[['months_bw_incident_and_bind','months_as_customer']].apply(lambda x: 1 if x.months_as_customer >= x.months_bw_incident_and_bind and x.months_bw_incident_and_bind > 0 else 0, axis=1)

# %%
df
# Out:
#      months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                   328   48       2014-10-17           OH    250/500
# 1                   228   42       2006-06-27           IN    250/500
# 2                   134   29       2000-09-06           OH    100/300
# 3                   256   41       1990-05-25           IL    250/500
# 4                   228   44       2014-06-06           IL   500/1000
# ..                  ...  ...              ...          ...        ...
# 995                   3   38       1991-07-16           OH   500/1000
# 996                 285   41       2014-01-05           IL    100/300
# 997                 130   34       2003-02-17           OH    250/500
# 998                 458   62       2011-11-18           IL   500/1000
# 999                 456   60       1996-11-11           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1406.91               0       466132
# 1                 2000                1197.22         5000000       468176
# 2                 2000                1413.14         5000000       430632
# 3                 2000                1415.74         6000000       608117
# 4                 1000                1583.91         6000000       610706
# ..                 ...                    ...             ...          ...
# 995               1000                1310.80               0       431289
# 996               1000                1436.79               0       608177
# 997                500                1383.49         3000000       442797
# 998               2000                1356.92         5000000       441714
# 999               1000                 766.19               0       612260
#
#     insured_sex  ... total_claim_amount injury_claim property_claim  \
# 0          MALE  ...              71610         6510          13020
# 1          MALE  ...               5070          780            780
# 2        FEMALE  ...              34650         7700           3850
# 3        FEMALE  ...              63400         6340           6340
# 4          MALE  ...               6500         1300            650
# ..          ...  ...                ...          ...            ...
# 995      FEMALE  ...              87200        17440           8720
# 996      FEMALE  ...             108480        18080          18080
# 997      FEMALE  ...              67500         7500           7500
# 998        MALE  ...              46980         5220           5220
# 999      FEMALE  ...               5060          460            920
#
#     vehicle_claim   auto_make  auto_model auto_year fraud_reported  \
# 0           52080        Saab         92x      2004              Y
# 1            3510    Mercedes        E400      2007              Y
# 2           23100       Dodge         RAM      2007              N
# 3           50720   Chevrolet       Tahoe      2014              Y
# 4            4550      Accura         RSX      2009              N
# ..            ...         ...         ...       ...            ...
# 995         61040       Honda      Accord      2006              N
# 996         72320  Volkswagen      Passat      2015              N
# 997         52500      Suburu     Impreza      1996              N
# 998         36540        Audi          A5      1998              N
# 999          3680    Mercedes        E400      2007              N
#
#     months_bw_incident_and_bind incident_within_customership
# 0                      3.333333                            1
# 1                    104.333333                            1
# 2                    176.066667                            0
# 3                    299.866667                            0
# 4                      8.533333                            1
# ..                          ...                          ...
# 995                  287.400000                            0
# 996                   12.800000                            1
# 997                  145.266667                            0
# 998                   39.866667                            1
# 999                  222.700000                            1
#
# [1000 rows x 40 columns]

# %%
df["capital-loss"]
# Out:
# 0          0
# 1          0
# 2          0
# 3     -62400
# 4     -46000
#        ...
# 995        0
# 996        0
# 997        0
# 998        0
# 999        0
# Name: capital-loss, Length: 1000, dtype: int64

# %%
df["capital-gains"]
# Out:
# 0      53300
# 1          0
# 2      35100
# 3      48900
# 4      66000
#        ...
# 995        0
# 996    70900
# 997    35100
# 998        0
# 999        0
# Name: capital-gains, Length: 1000, dtype: int64

# %%
df['capital-loss'] = df['capital-loss'].abs()

# %%
print (df[df['total_claim_amount'] != df['injury_claim'] + df['property_claim']+ df['vehicle_claim']].shape[0])
# Out:
# 0

# %%
for i in dict(df.dtypes):
 if (dict(df.dtypes)[i] == 'int64' or dict(df.dtypes)[i] ==   'float64'):
  print(i , " : ", df[df[i]<0].shape[0])  # This code is useful for quickly identifying numeric columns that contain negative values. This information can be helpful for data cleaning, preprocessing, or exploratory data analysis.
# Out:
# months_as_customer  :  0
# age  :  0
# policy_deductable  :  0
# policy_annual_premium  :  0
# umbrella_limit  :  1
# insured_zip  :  0
# capital-gains  :  0
# capital-loss  :  0
# incident_hour_of_the_day  :  0
# number_of_vehicles_involved  :  0
# bodily_injuries  :  0
# witnesses  :  0
# total_claim_amount  :  0
# injury_claim  :  0
# property_claim  :  0
# vehicle_claim  :  0
# auto_year  :  0
# months_bw_incident_and_bind  :  1
# incident_within_customership  :  0

# %%
df["umbrella_limit"]
# Out:
# 0            0
# 1      5000000
# 2      5000000
# 3      6000000
# 4      6000000
#         ...
# 995          0
# 996          0
# 997    3000000
# 998    5000000
# 999          0
# Name: umbrella_limit, Length: 1000, dtype: int64

# %%
df["months_bw_incident_and_bind"]
# Out:
# 0        3.333333
# 1      104.333333
# 2      176.066667
# 3      299.866667
# 4        8.533333
#           ...
# 995    287.400000
# 996     12.800000
# 997    145.266667
# 998     39.866667
# 999    222.700000
# Name: months_bw_incident_and_bind, Length: 1000, dtype: float64

# %%
df.drop(df.index[df[df['umbrella_limit']<0].index[0]], inplace = True)
print(df[df['umbrella_limit']<0].shape[0])
# Out:
# 0

# %%
df.drop([df[df['months_bw_incident_and_bind']<0].index[0]], inplace = True)
print(df[df['months_bw_incident_and_bind']<0].shape[0])
# Out:
# 0

# %%
for i in dict(df.dtypes):
 if (dict(df.dtypes)[i] == 'int64' or dict(df.dtypes)[i] ==   'float64'):
  print(i , " : ", df[df[i]<0].shape[0])
# Out:
# months_as_customer  :  0
# age  :  0
# policy_deductable  :  0
# policy_annual_premium  :  0
# umbrella_limit  :  0
# insured_zip  :  0
# capital-gains  :  0
# capital-loss  :  0
# incident_hour_of_the_day  :  0
# number_of_vehicles_involved  :  0
# bodily_injuries  :  0
# witnesses  :  0
# total_claim_amount  :  0
# injury_claim  :  0
# property_claim  :  0
# vehicle_claim  :  0
# auto_year  :  0
# months_bw_incident_and_bind  :  0
# incident_within_customership  :  0

# %%
df[df['months_bw_incident_and_bind']<0]
# Out:
# Empty DataFrame
# Columns: [months_as_customer, age, policy_state, policy_csl, policy_deductable, policy_annual_premium, insured_zip, insured_education_level, insured_occupation, insured_hobbies, insured_relationship, capital-gains, capital-loss, collision_type, incident_severity, authorities_contacted, incident_state, incident_city, incident_hour_of_the_day, bodily_injuries, witnesses, total_claim_amount, injury_claim, property_claim, auto_make, auto_model, auto_year, fraud_reported, months_bw_incident_and_bind]
# Index: []
#
# [0 rows x 29 columns]

# %%
print(df[df['months_bw_incident_and_bind']<0])
# Out:
# Empty DataFrame
# Columns: [months_as_customer, age, policy_bind_date, policy_state, policy_csl, policy_deductable, policy_annual_premium, umbrella_limit, insured_zip, insured_sex, insured_education_level, insured_occupation, insured_hobbies, insured_relationship, capital-gains, capital-loss, incident_date, incident_type, collision_type, incident_severity, authorities_contacted, incident_state, incident_city, incident_location, incident_hour_of_the_day, number_of_vehicles_involved, property_damage, bodily_injuries, witnesses, police_report_available, total_claim_amount, injury_claim, property_claim, vehicle_claim, auto_make, auto_model, auto_year, fraud_reported, months_bw_incident_and_bind, incident_within_customership]
# Index: []
#
# [0 rows x 40 columns]

# %%
print(df[df['months_bw_incident_and_bind']<0])
# Out:
# Empty DataFrame
# Columns: [months_as_customer, age, policy_state, policy_csl, policy_deductable, policy_annual_premium, insured_zip, insured_education_level, insured_occupation, insured_hobbies, insured_relationship, capital-gains, capital-loss, collision_type, incident_severity, authorities_contacted, incident_state, incident_city, incident_hour_of_the_day, bodily_injuries, witnesses, total_claim_amount, injury_claim, property_claim, auto_make, auto_model, auto_year, fraud_reported, months_bw_incident_and_bind]
# Index: []
#
# [0 rows x 29 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for i in dict(df.dtypes):
 if dict(df.dtypes)[i] == 'int64' or dict(df.dtypes)[i] ==  'float64':
  sns.distplot(df[i])
  plt.title("Detecting outliers using Boxplot")
  plt.xlabel(i)
  plt.show()
# Out:
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-36-69a0e498742b>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])

# %%
import numpy as np
outliers = []
def detect_outliers_zscore(data):
 thres = 3
 mean = np.mean(data)
 std = np.std(data)
 for i in data:
  z_score = (i-mean)/std
  if (np.abs(z_score) > thres):
   outliers.append(i)
 return outliers

# %%
df['umbrella_limit'].median()
# Out:
# 0.0

# %%
df['policy_annual_premium'].median()
# Out:
# 1257.1999999999998

# %%
for i in dict(df.dtypes):
 outliers = []
 if dict(df.dtypes)[i] == 'int64' or dict(df.dtypes)[i] ==  'float64':
  sample_outliers = detect_outliers_zscore(df[i])
  print("Column: ", i)
  print("Outliers from Z-scores method: ", sample_outliers)
  if len(sample_outliers) > 0:
   median = np.median(df[i])
   print(median)
   for j in sample_outliers:
    df[i] = np.where(df[i]==j, median, df[i])
   print("After treatment: ")
   outliers = []
   sample_outliers = detect_outliers_zscore(df[i])
   print("Outliers from Z-scores method: ", sample_outliers)
  print("*************************************************************")
# Out:
# Column:  months_as_customer
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  age
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  policy_deductable
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  policy_annual_premium
# Outliers from Z-scores method:  [2047.59, 433.33, 484.67]
# 1257.1999999999998
# After treatment:
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  umbrella_limit
# Outliers from Z-scores method:  [8000000, 8000000, 9000000, 10000000, 8000000, 8000000, 8000000, 10000000, 9000000, 8000000, 9000000, 9000000, 8000000, 8000000, 9000000]
# 0.0
# After treatment:
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  insured_zip
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  capital-gains
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  capital-loss
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  incident_hour_of_the_day
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  number_of_vehicles_involved
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  bodily_injuries
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  witnesses
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  total_claim_amount
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  injury_claim
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  property_claim
# Outliers from Z-scores method:  [23670]
# 6745.0
# After treatment:
# Outliers from Z-scores method:  [21810.0]
# *************************************************************
# Column:  vehicle_claim
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  auto_year
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  months_bw_incident_and_bind
# Outliers from Z-scores method:  []
# *************************************************************
# Column:  incident_within_customership
# Outliers from Z-scores method:  []
# *************************************************************

# %%
df = df.replace("?", np.NaN)
for i in df.columns:
 print ("Column: ", i)
 print ("Number of nulls: ", df[i].isnull().sum())
# Out:
# Column:  months_as_customer
# Number of nulls:  0
# Column:  age
# Number of nulls:  0
# Column:  policy_bind_date
# Number of nulls:  0
# Column:  policy_state
# Number of nulls:  0
# Column:  policy_csl
# Number of nulls:  0
# Column:  policy_deductable
# Number of nulls:  0
# Column:  policy_annual_premium
# Number of nulls:  0
# Column:  umbrella_limit
# Number of nulls:  0
# Column:  insured_zip
# Number of nulls:  0
# Column:  insured_sex
# Number of nulls:  0
# Column:  insured_education_level
# Number of nulls:  0
# Column:  insured_occupation
# Number of nulls:  0
# Column:  insured_hobbies
# Number of nulls:  0
# Column:  insured_relationship
# Number of nulls:  0
# Column:  capital-gains
# Number of nulls:  0
# Column:  capital-loss
# Number of nulls:  0
# Column:  incident_date
# Number of nulls:  0
# Column:  incident_type
# Number of nulls:  0
# Column:  collision_type
# Number of nulls:  178
# Column:  incident_severity
# Number of nulls:  0
# Column:  authorities_contacted
# Number of nulls:  91
# Column:  incident_state
# Number of nulls:  0
# Column:  incident_city
# Number of nulls:  0
# Column:  incident_location
# Number of nulls:  0
# Column:  incident_hour_of_the_day
# Number of nulls:  0
# Column:  number_of_vehicles_involved
# Number of nulls:  0
# Column:  property_damage
# Number of nulls:  360
# Column:  bodily_injuries
# Number of nulls:  0
# Column:  witnesses
# Number of nulls:  0
# Column:  police_report_available
# Number of nulls:  342
# Column:  total_claim_amount
# Number of nulls:  0
# Column:  injury_claim
# Number of nulls:  0
# Column:  property_claim
# Number of nulls:  0
# Column:  vehicle_claim
# Number of nulls:  0
# Column:  auto_make
# Number of nulls:  0
# Column:  auto_model
# Number of nulls:  0
# Column:  auto_year
# Number of nulls:  0
# Column:  fraud_reported
# Number of nulls:  0
# Column:  months_bw_incident_and_bind
# Number of nulls:  0
# Column:  incident_within_customership
# Number of nulls:  0

# %%
df.nunique()
# Out:
# months_as_customer              390
# age                              46
# policy_bind_date                949
# policy_state                      3
# policy_csl                        3
# policy_deductable                 3
# policy_annual_premium           987
# umbrella_limit                    7
# insured_zip                     993
# insured_sex                       2
# insured_education_level           7
# insured_occupation               14
# insured_hobbies                  20
# insured_relationship              6
# capital-gains                   338
# capital-loss                    354
# incident_date                    60
# incident_type                     4
# collision_type                    3
# incident_severity                 4
# authorities_contacted             4
# incident_state                    7
# incident_city                     7
# incident_location               998
# incident_hour_of_the_day         24
# number_of_vehicles_involved       4
# property_damage                   2
# bodily_injuries                   3
# witnesses                         4
# police_report_available           2
# total_claim_amount              761
# injury_claim                    638
# property_claim                  625
# vehicle_claim                   724
# auto_make                        14
# auto_model                       39
# auto_year                        21
# fraud_reported                    2
# months_bw_incident_and_bind     952
# incident_within_customership      2
# dtype: int64

# %%
df['incident_location']
# Out:
# 0           9935 4th Drive
# 1             6608 MLK Hwy
# 2        7121 Francis Lane
# 3         6956 Maple Drive
# 4             3041 3rd Ave
#               ...
# 995     6045 Andromedia St
# 996       3092 Texas Drive
# 997            7629 5th St
# 998          6128 Elm Lane
# 999    1416 Cherokee Ridge
# Name: incident_location, Length: 998, dtype: object

# %%
df.shape
# Out:
# (998, 40)

# %%
df['collision_type'].mode()[0]
# Out:
# 'Rear Collision'

# %%
df['collision_type'].isnull().sum()
# Out:
# 178

# %%
df['collision_type'].value_counts()
# Out:
# collision_type
# Rear Collision     291
# Side Collision     275
# Front Collision    254
# Name: count, dtype: int64

# %%
df['property_damage'].isnull().sum()
# Out:
# 360

# %%
df['property_damage'].value_counts()
# Out:
# property_damage
# NO     338
# YES    300
# Name: count, dtype: int64

# %%
df = df.drop('incident_location', axis = 1)
#Missing values here are treated with Mode imputation as values were missing in categorical columns
df['collision_type'] = df['collision_type'].fillna(df['collision_type'].mode()[0])
df['property_damage'] = df['property_damage'].fillna(df['property_damage'].mode()[0])
df['police_report_available'] = df['police_report_available'].fillna(df['police_report_available'].mode()[0])

# %%
df.dtypes
# Out:
# months_as_customer                       int64
# age                                      int64
# policy_bind_date                datetime64[ns]
# policy_state                            object
# policy_csl                              object
# policy_deductable                        int64
# policy_annual_premium                  float64
# umbrella_limit                         float64
# insured_zip                              int64
# insured_sex                             object
# insured_education_level                 object
# insured_occupation                      object
# insured_hobbies                         object
# insured_relationship                    object
# capital-gains                            int64
# capital-loss                             int64
# incident_date                   datetime64[ns]
# incident_type                           object
# collision_type                          object
# incident_severity                       object
# authorities_contacted                   object
# incident_state                          object
# incident_city                           object
# incident_hour_of_the_day                 int64
# number_of_vehicles_involved              int64
# property_damage                         object
# bodily_injuries                          int64
# witnesses                                int64
# police_report_available                 object
# total_claim_amount                       int64
# injury_claim                             int64
# property_claim                         float64
# vehicle_claim                            int64
# auto_make                               object
# auto_model                              object
# auto_year                                int64
# fraud_reported                          object
# months_bw_incident_and_bind            float64
# incident_within_customership             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 998 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   months_as_customer            998 non-null    int64
#  1   age                           998 non-null    int64
#  2   policy_bind_date              998 non-null    datetime64[ns]
#  3   policy_state                  998 non-null    object
#  4   policy_csl                    998 non-null    object
#  5   policy_deductable             998 non-null    int64
#  6   policy_annual_premium         998 non-null    float64
#  7   umbrella_limit                998 non-null    float64
#  8   insured_zip                   998 non-null    int64
#  9   insured_sex                   998 non-null    object
#  10  insured_education_level       998 non-null    object
#  11  insured_occupation            998 non-null    object
#  12  insured_hobbies               998 non-null    object
#  13  insured_relationship          998 non-null    object
#  14  capital-gains                 998 non-null    int64
#  15  capital-loss                  998 non-null    int64
#  16  incident_date                 998 non-null    datetime64[ns]
#  17  incident_type                 998 non-null    object
#  18  collision_type                998 non-null    object
#  19  incident_severity             998 non-null    object
#  20  authorities_contacted         907 non-null    object
#  21  incident_state                998 non-null    object
#  22  incident_city                 998 non-null    object
#  23  incident_hour_of_the_day      998 non-null    int64
#  24  number_of_vehicles_involved   998 non-null    int64
#  25  property_damage               998 non-null    object
#  26  bodily_injuries               998 non-null    int64
#  27  witnesses                     998 non-null    int64
#  28  police_report_available       998 non-null    object
#  29  total_claim_amount            998 non-null    int64
#  30  injury_claim                  998 non-null    int64
#  31  property_claim                998 non-null    float64
#  32  vehicle_claim                 998 non-null    int64
#  33  auto_make                     998 non-null    object
#  34  auto_model                    998 non-null    object
#  35  auto_year                     998 non-null    int64
#  36  fraud_reported                998 non-null    object
#  37  months_bw_incident_and_bind   998 non-null    float64
#  38  incident_within_customership  998 non-null    int64
# dtypes: datetime64[ns](2), float64(4), int64(15), object(18)
# memory usage: 311.9+ KB

# %%
df["policy_state"].value_counts()
# Out:
# policy_state
# OH    351
# IL    338
# IN    309
# Name: count, dtype: int64

# %%
df["policy_state"].unique()
# Out:
# array(['OH', 'IN', 'IL'], dtype=object)

# %%
range(len(df["policy_state"].unique()))
# Out:
# range(0, 3)

# %%
zip(df[i].unique(), range(len(df[i].unique())))

# %%
dict(zip(df["policy_state"].unique(), range(len(df["policy_state"].unique()))))
# Out:
# {'OH': 0, 'IN': 1, 'IL': 2}

# %%
mappings = {}
for i in dict(df.dtypes):
 if dict(df.dtypes)[i] == 'O':
  mappings[i] = dict(zip(df[i].unique(), range(len(df[i].unique()))))
  df[i] = df[i].map(lambda x: mappings[i][x])
df
# Out:
#      months_as_customer  age policy_bind_date  policy_state  policy_csl  \
# 0                   328   48       2014-10-17             0           0
# 1                   228   42       2006-06-27             1           0
# 2                   134   29       2000-09-06             0           1
# 3                   256   41       1990-05-25             2           0
# 4                   228   44       2014-06-06             2           2
# ..                  ...  ...              ...           ...         ...
# 995                   3   38       1991-07-16             0           2
# 996                 285   41       2014-01-05             2           1
# 997                 130   34       2003-02-17             0           0
# 998                 458   62       2011-11-18             2           2
# 999                 456   60       1996-11-11             0           0
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1406.91             0.0       466132
# 1                 2000                1197.22       5000000.0       468176
# 2                 2000                1413.14       5000000.0       430632
# 3                 2000                1415.74       6000000.0       608117
# 4                 1000                1583.91       6000000.0       610706
# ..                 ...                    ...             ...          ...
# 995               1000                1310.80             0.0       431289
# 996               1000                1436.79             0.0       608177
# 997                500                1383.49       3000000.0       442797
# 998               2000                1356.92       5000000.0       441714
# 999               1000                 766.19             0.0       612260
#
#      insured_sex  ...  total_claim_amount  injury_claim  property_claim  \
# 0              0  ...               71610          6510         13020.0
# 1              0  ...                5070           780           780.0
# 2              1  ...               34650          7700          3850.0
# 3              1  ...               63400          6340          6340.0
# 4              0  ...                6500          1300           650.0
# ..           ...  ...                 ...           ...             ...
# 995            1  ...               87200         17440          8720.0
# 996            1  ...              108480         18080         18080.0
# 997            1  ...               67500          7500          7500.0
# 998            0  ...               46980          5220          5220.0
# 999            1  ...                5060           460           920.0
#
#      vehicle_claim  auto_make  auto_model auto_year  fraud_reported  \
# 0            52080          0           0      2004               0
# 1             3510          1           1      2007               0
# 2            23100          2           2      2007               1
# 3            50720          3           3      2014               0
# 4             4550          4           4      2009               1
# ..             ...        ...         ...       ...             ...
# 995          61040         12          31      2006               1
# 996          72320         13          27      2015               1
# 997          52500          9          17      1996               1
# 998          36540          6           7      1998               1
# 999           3680          1           1      2007               1
#
#      months_bw_incident_and_bind  incident_within_customership
# 0                       3.333333                             1
# 1                     104.333333                             1
# 2                     176.066667                             0
# 3                     299.866667                             0
# 4                       8.533333                             1
# ..                           ...                           ...
# 995                   287.400000                             0
# 996                    12.800000                             1
# 997                   145.266667                             0
# 998                    39.866667                             1
# 999                   222.700000                             1
#
# [998 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 998 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   months_as_customer            998 non-null    int64
#  1   age                           998 non-null    int64
#  2   policy_bind_date              998 non-null    datetime64[ns]
#  3   policy_state                  998 non-null    int64
#  4   policy_csl                    998 non-null    int64
#  5   policy_deductable             998 non-null    int64
#  6   policy_annual_premium         998 non-null    float64
#  7   umbrella_limit                998 non-null    float64
#  8   insured_zip                   998 non-null    int64
#  9   insured_sex                   998 non-null    int64
#  10  insured_education_level       998 non-null    int64
#  11  insured_occupation            998 non-null    int64
#  12  insured_hobbies               998 non-null    int64
#  13  insured_relationship          998 non-null    int64
#  14  capital-gains                 998 non-null    int64
#  15  capital-loss                  998 non-null    int64
#  16  incident_date                 998 non-null    datetime64[ns]
#  17  incident_type                 998 non-null    int64
#  18  collision_type                998 non-null    int64
#  19  incident_severity             998 non-null    int64
#  20  authorities_contacted         998 non-null    int64
#  21  incident_state                998 non-null    int64
#  22  incident_city                 998 non-null    int64
#  23  incident_hour_of_the_day      998 non-null    int64
#  24  number_of_vehicles_involved   998 non-null    int64
#  25  property_damage               998 non-null    int64
#  26  bodily_injuries               998 non-null    int64
#  27  witnesses                     998 non-null    int64
#  28  police_report_available       998 non-null    int64
#  29  total_claim_amount            998 non-null    int64
#  30  injury_claim                  998 non-null    int64
#  31  property_claim                998 non-null    float64
#  32  vehicle_claim                 998 non-null    int64
#  33  auto_make                     998 non-null    int64
#  34  auto_model                    998 non-null    int64
#  35  auto_year                     998 non-null    int64
#  36  fraud_reported                998 non-null    int64
#  37  months_bw_incident_and_bind   998 non-null    float64
#  38  incident_within_customership  998 non-null    int64
# dtypes: datetime64[ns](2), float64(4), int64(33)
# memory usage: 311.9 KB

# %%
import seaborn as sns

# %%
df.corr()
# Out:
#                               months_as_customer       age  policy_bind_date  \
# months_as_customer                      1.000000  0.922012         -0.050986
# age                                     0.922012  1.000000         -0.039288
# policy_bind_date                       -0.050986 -0.039288          1.000000
# policy_state                            0.001129  0.014934          0.004285
# policy_csl                             -0.006773 -0.008226         -0.001946
# policy_deductable                       0.028012  0.029904         -0.051304
# policy_annual_premium                   0.001539  0.009296          0.002826
# umbrella_limit                          0.022245  0.015446          0.045238
# insured_zip                             0.019391  0.026592         -0.000213
# insured_sex                            -0.058376 -0.071596          0.033840
# insured_education_level                -0.072776 -0.074502          0.042958
# insured_occupation                      0.007542  0.009128         -0.041024
# insured_hobbies                        -0.021819 -0.013552         -0.043575
# insured_relationship                    0.030637  0.055073         -0.019732
# capital-gains                           0.005377 -0.008085          0.039765
# capital-loss                           -0.017842 -0.005694          0.028525
# incident_date                          -0.041565 -0.033385          0.062984
# incident_type                          -0.015043 -0.007806          0.022559
# collision_type                          0.073879  0.076201         -0.027984
# incident_severity                      -0.060484 -0.059392          0.001613
# authorities_contacted                  -0.011340 -0.012544          0.046899
# incident_state                          0.000351  0.011962         -0.027746
# incident_city                          -0.017723 -0.006912         -0.050263
# incident_hour_of_the_day                0.069760  0.086510          0.035180
# number_of_vehicles_involved             0.015055  0.022184          0.024563
# property_damage                        -0.001641  0.006114         -0.017536
# bodily_injuries                        -0.009359 -0.015314          0.027798
# witnesses                               0.056353  0.050664          0.053986
# police_report_available                 0.024468  0.022382          0.016413
# total_claim_amount                      0.061323  0.069587          0.002028
# injury_claim                            0.065135  0.075403          0.002332
# property_claim                          0.039926  0.064469         -0.000377
# vehicle_claim                           0.060328  0.062388          0.001803
# auto_make                              -0.036540 -0.032192          0.013566
# auto_model                              0.013600  0.024348          0.050125
# auto_year                               0.001412  0.002368          0.013372
# fraud_reported                         -0.022045 -0.013174          0.000767
# months_bw_incident_and_bind             0.050739  0.039089         -0.999979
# incident_within_customership            0.581539  0.525311          0.513291
#
#                               policy_state  policy_csl  policy_deductable  \
# months_as_customer                0.001129   -0.006773           0.028012
# age                               0.014934   -0.008226           0.029904
# policy_bind_date                  0.004285   -0.001946          -0.051304
# policy_state                      1.000000    0.028972          -0.011280
# policy_csl                        0.028972    1.000000           0.003738
# policy_deductable                -0.011280    0.003738           1.000000
# policy_annual_premium            -0.012031   -0.001257          -0.006596
# umbrella_limit                    0.006119   -0.026163           0.013169
# insured_zip                      -0.009827   -0.005917           0.003531
# insured_sex                      -0.021785    0.069626           0.008385
# insured_education_level           0.030506   -0.043242          -0.064895
# insured_occupation               -0.015571    0.019228           0.020771
# insured_hobbies                   0.040065   -0.020299           0.024728
# insured_relationship              0.016000    0.004037          -0.009674
# capital-gains                    -0.075753   -0.000509           0.034523
# capital-loss                     -0.031508    0.007008           0.022371
# incident_date                    -0.030052   -0.025777          -0.036617
# incident_type                     0.030025   -0.003263           0.034495
# collision_type                    0.050923   -0.017183           0.052597
# incident_severity                 0.024912   -0.002360          -0.016858
# authorities_contacted            -0.000894   -0.011877          -0.006990
# incident_state                    0.015018   -0.022481          -0.021401
# incident_city                    -0.030053    0.010521           0.009016
# incident_hour_of_the_day         -0.029258   -0.004658           0.061289
# number_of_vehicles_involved       0.041325   -0.004903           0.050438
# property_damage                  -0.010279    0.008058          -0.017744
# bodily_injuries                  -0.014844    0.016157          -0.024054
# witnesses                        -0.023543    0.013774           0.066593
# police_report_available           0.069986    0.054478          -0.037734
# total_claim_amount                0.007883    0.011858           0.024503
# injury_claim                      0.046597   -0.007662           0.039390
# property_claim                   -0.001857    0.009377           0.071159
# vehicle_claim                     0.000501    0.015009           0.006937
# auto_make                         0.045031   -0.004693           0.039566
# auto_model                        0.036540    0.010044           0.007199
# auto_year                        -0.003915   -0.034203           0.024493
# fraud_reported                    0.030134    0.042158          -0.014106
# months_bw_incident_and_bind      -0.004480    0.001781           0.051089
# incident_within_customership      0.012237    0.026951          -0.003131
#
#                               policy_annual_premium  umbrella_limit  \
# months_as_customer                         0.001539        0.022245
# age                                        0.009296        0.015446
# policy_bind_date                           0.002826        0.045238
# policy_state                              -0.012031        0.006119
# policy_csl                                -0.001257       -0.026163
# policy_deductable                         -0.006596        0.013169
# policy_annual_premium                      1.000000       -0.014270
# umbrella_limit                            -0.014270        1.000000
# insured_zip                                0.045238       -0.000195
# insured_sex                               -0.044247       -0.021538
# insured_education_level                   -0.001524        0.017676
# insured_occupation                         0.030116       -0.041625
# insured_hobbies                            0.018832       -0.024017
# insured_relationship                      -0.002030       -0.004889
# capital-gains                             -0.010002       -0.020281
# capital-loss                              -0.028968        0.022418
# incident_date                             -0.031091       -0.005182
# incident_type                             -0.054240       -0.004218
# collision_type                            -0.032194       -0.009505
# incident_severity                         -0.013994       -0.002227
# authorities_contacted                      0.034983       -0.021725
# incident_state                             0.002418        0.017750
# incident_city                              0.004511        0.060512
# incident_hour_of_the_day                  -0.003292       -0.018971
# number_of_vehicles_involved               -0.042772       -0.043465
# property_damage                           -0.081383        0.078398
# bodily_injuries                            0.023611        0.049266
# witnesses                                  0.005814       -0.003366
# police_report_available                   -0.029055        0.035061
# total_claim_amount                         0.000767       -0.046510
# injury_claim                              -0.024095       -0.046227
# property_claim                            -0.008309       -0.018857
# vehicle_claim                              0.010924       -0.047858
# auto_make                                  0.000523       -0.011091
# auto_model                                 0.017534        0.014746
# auto_year                                 -0.039698        0.028427
# fraud_reported                             0.009673       -0.041036
# months_bw_incident_and_bind               -0.003027       -0.045289
# incident_within_customership              -0.000182        0.017858
#
#                               insured_zip  insured_sex  ...  \
# months_as_customer               0.019391    -0.058376  ...
# age                              0.026592    -0.071596  ...
# policy_bind_date                -0.000213     0.033840  ...
# policy_state                    -0.009827    -0.021785  ...
# policy_csl                      -0.005917     0.069626  ...
# policy_deductable                0.003531     0.008385  ...
# policy_annual_premium            0.045238    -0.044247  ...
# umbrella_limit                  -0.000195    -0.021538  ...
# insured_zip                      1.000000     0.035561  ...
# insured_sex                      0.035561     1.000000  ...
# insured_education_level         -0.016318    -0.006901  ...
# insured_occupation              -0.048146     0.015762  ...
# insured_hobbies                  0.010192     0.028077  ...
# insured_relationship            -0.028076     0.007376  ...
# capital-gains                    0.005930     0.020541  ...
# capital-loss                    -0.050718    -0.023813  ...
# incident_date                   -0.015771     0.022241  ...
# incident_type                    0.044335    -0.003802  ...
# collision_type                   0.015734    -0.015743  ...
# incident_severity               -0.024610     0.027811  ...
# authorities_contacted            0.001593    -0.019196  ...
# incident_state                   0.019307    -0.047381  ...
# incident_city                    0.002140     0.023141  ...
# incident_hour_of_the_day         0.008672    -0.018582  ...
# number_of_vehicles_involved      0.026817    -0.019541  ...
# property_damage                 -0.025967     0.023770  ...
# bodily_injuries                  0.027668     0.019037  ...
# witnesses                        0.020071    -0.041557  ...
# police_report_available         -0.009937     0.006142  ...
# total_claim_amount              -0.032576     0.025412  ...
# injury_claim                    -0.017261    -0.000581  ...
# property_claim                  -0.010570     0.014020  ...
# vehicle_claim                   -0.039792     0.031287  ...
# auto_make                       -0.021730    -0.027224  ...
# auto_model                      -0.025442    -0.024305  ...
# auto_year                       -0.034287     0.026298  ...
# fraud_reported                  -0.018617     0.032157  ...
# months_bw_incident_and_bind      0.000112    -0.033710  ...
# incident_within_customership     0.029066    -0.021549  ...
#
#                               total_claim_amount  injury_claim  \
# months_as_customer                      0.061323      0.065135
# age                                     0.069587      0.075403
# policy_bind_date                        0.002028      0.002332
# policy_state                            0.007883      0.046597
# policy_csl                              0.011858     -0.007662
# policy_deductable                       0.024503      0.039390
# policy_annual_premium                   0.000767     -0.024095
# umbrella_limit                         -0.046510     -0.046227
# insured_zip                            -0.032576     -0.017261
# insured_sex                             0.025412     -0.000581
# insured_education_level                -0.038928     -0.014461
# insured_occupation                      0.004692     -0.003790
# insured_hobbies                         0.044991      0.044601
# insured_relationship                    0.014928      0.061833
# capital-gains                           0.017489      0.026085
# capital-loss                            0.037580      0.046408
# incident_date                          -0.050708     -0.033580
# incident_type                          -0.319206     -0.228406
# collision_type                          0.013995      0.025328
# incident_severity                      -0.364138     -0.277098
# authorities_contacted                   0.347742      0.271804
# incident_state                         -0.070668     -0.072030
# incident_city                          -0.009662      0.008618
# incident_hour_of_the_day                0.217724      0.165708
# number_of_vehicles_involved             0.276019      0.224913
# property_damage                        -0.058511     -0.048515
# bodily_injuries                         0.049090      0.047634
# witnesses                              -0.010365     -0.024888
# police_report_available                -0.037334     -0.028276
# total_claim_amount                      1.000000      0.805687
# injury_claim                            0.805687      1.000000
# property_claim                          0.810280      0.567485
# vehicle_claim                           0.982733      0.723493
# auto_make                              -0.003613      0.005020
# auto_model                              0.015936      0.022520
# auto_year                              -0.033507     -0.013354
# fraud_reported                         -0.164773     -0.091190
# months_bw_incident_and_bind            -0.002355     -0.002549
# incident_within_customership           -0.017874     -0.005370
#
#                               property_claim  vehicle_claim  auto_make  \
# months_as_customer                  0.039926       0.060328  -0.036540
# age                                 0.064469       0.062388  -0.032192
# policy_bind_date                   -0.000377       0.001803   0.013566
# policy_state                       -0.001857       0.000501   0.045031
# policy_csl                          0.009377       0.015009  -0.004693
# policy_deductable                   0.071159       0.006937   0.039566
# policy_annual_premium              -0.008309       0.010924   0.000523
# umbrella_limit                     -0.018857      -0.047858  -0.011091
# insured_zip                        -0.010570      -0.039792  -0.021730
# insured_sex                         0.014020       0.031287  -0.027224
# insured_education_level            -0.036195      -0.042808   0.043936
# insured_occupation                  0.004143       0.007873   0.033779
# insured_hobbies                     0.051635       0.037820   0.030382
# insured_relationship               -0.009448       0.008025   0.007171
# capital-gains                      -0.002480       0.017456   0.022229
# capital-loss                        0.028483       0.034159   0.020097
# incident_date                      -0.071488      -0.042528   0.033049
# incident_type                      -0.232941      -0.327031  -0.001332
# collision_type                      0.011374       0.011333   0.046426
# incident_severity                  -0.301404      -0.360699  -0.007380
# authorities_contacted               0.277212       0.346615  -0.015271
# incident_state                     -0.051945      -0.065849   0.016356
# incident_city                      -0.018815      -0.012367   0.006606
# incident_hour_of_the_day            0.178810       0.215688  -0.004664
# number_of_vehicles_involved         0.225454       0.271202  -0.008866
# property_damage                    -0.044744      -0.058480   0.047371
# bodily_injuries                     0.038203       0.045504   0.015979
# witnesses                           0.049039      -0.021722  -0.043481
# police_report_available            -0.008531      -0.041383  -0.059074
# total_claim_amount                  0.810280       0.982733  -0.003613
# injury_claim                        0.567485       0.723493   0.005020
# property_claim                      1.000000       0.732261   0.025877
# vehicle_claim                       0.732261       1.000000  -0.014196
# auto_make                           0.025877      -0.014196   1.000000
# auto_model                          0.020828       0.010295   0.483817
# auto_year                          -0.010277      -0.040464   0.039376
# fraud_reported                     -0.142212      -0.171182   0.007965
# months_bw_incident_and_bind        -0.000082      -0.002077  -0.013359
# incident_within_customership       -0.015862      -0.018447  -0.009452
#
#                               auto_model  auto_year  fraud_reported  \
# months_as_customer              0.013600   0.001412       -0.022045
# age                             0.024348   0.002368       -0.013174
# policy_bind_date                0.050125   0.013372        0.000767
# policy_state                    0.036540  -0.003915        0.030134
# policy_csl                      0.010044  -0.034203        0.042158
# policy_deductable               0.007199   0.024493       -0.014106
# policy_annual_premium           0.017534  -0.039698        0.009673
# umbrella_limit                  0.014746   0.028427       -0.041036
# insured_zip                    -0.025442  -0.034287       -0.018617
# insured_sex                    -0.024305   0.026298        0.032157
# insured_education_level         0.008692   0.040300        0.004151
# insured_occupation              0.044838  -0.029524        0.018706
# insured_hobbies                 0.068079  -0.025746       -0.103816
# insured_relationship            0.021542  -0.020253       -0.026096
# capital-gains                  -0.034839   0.030412        0.019192
# capital-loss                    0.016015   0.054950       -0.013785
# incident_date                   0.018147  -0.012740        0.050683
# incident_type                  -0.039316   0.073878        0.071251
# collision_type                  0.059291  -0.000825       -0.016582
# incident_severity               0.000238  -0.021303        0.406823
# authorities_contacted           0.007530  -0.055503       -0.108889
# incident_state                  0.015610  -0.004614        0.028157
# incident_city                  -0.020589   0.021135        0.023871
# incident_hour_of_the_day        0.041266   0.021863       -0.004707
# number_of_vehicles_involved    -0.025966   0.033413       -0.051492
# property_damage                 0.052530   0.034995        0.018997
# bodily_injuries                 0.036129  -0.022402       -0.033223
# witnesses                      -0.002421   0.045708       -0.050095
# police_report_available         0.043242   0.022903       -0.027353
# total_claim_amount              0.015936  -0.033507       -0.164773
# injury_claim                    0.022520  -0.013354       -0.091190
# property_claim                  0.020828  -0.010277       -0.142212
# vehicle_claim                   0.010295  -0.040464       -0.171182
# auto_make                       0.483817   0.039376        0.007965
# auto_model                      1.000000   0.012333        0.004596
# auto_year                       0.012333   1.000000       -0.006869
# fraud_reported                  0.004596  -0.006869        1.000000
# months_bw_incident_and_bind    -0.050028  -0.013459       -0.000442
# incident_within_customership    0.053055   0.018915       -0.000134
#
#                               months_bw_incident_and_bind  \
# months_as_customer                               0.050739
# age                                              0.039089
# policy_bind_date                                -0.999979
# policy_state                                    -0.004480
# policy_csl                                       0.001781
# policy_deductable                                0.051089
# policy_annual_premium                           -0.003027
# umbrella_limit                                  -0.045289
# insured_zip                                      0.000112
# insured_sex                                     -0.033710
# insured_education_level                         -0.042635
# insured_occupation                               0.041472
# insured_hobbies                                  0.043764
# insured_relationship                             0.019457
# capital-gains                                   -0.039901
# capital-loss                                    -0.028545
# incident_date                                   -0.056580
# incident_type                                   -0.021925
# collision_type                                   0.027785
# incident_severity                               -0.001326
# authorities_contacted                           -0.046969
# incident_state                                   0.028098
# incident_city                                    0.050448
# incident_hour_of_the_day                        -0.035272
# number_of_vehicles_involved                     -0.024312
# property_damage                                  0.017502
# bodily_injuries                                 -0.027865
# witnesses                                       -0.053921
# police_report_available                         -0.016555
# total_claim_amount                              -0.002355
# injury_claim                                    -0.002549
# property_claim                                  -0.000082
# vehicle_claim                                   -0.002077
# auto_make                                       -0.013359
# auto_model                                      -0.050028
# auto_year                                       -0.013459
# fraud_reported                                  -0.000442
# months_bw_incident_and_bind                      1.000000
# incident_within_customership                    -0.513638
#
#                               incident_within_customership
# months_as_customer                                0.581539
# age                                               0.525311
# policy_bind_date                                  0.513291
# policy_state                                      0.012237
# policy_csl                                        0.026951
# policy_deductable                                -0.003131
# policy_annual_premium                            -0.000182
# umbrella_limit                                    0.017858
# insured_zip                                       0.029066
# insured_sex                                      -0.021549
# insured_education_level                          -0.029163
# insured_occupation                               -0.044734
# insured_hobbies                                  -0.045542
# insured_relationship                             -0.024630
# capital-gains                                    -0.000047
# capital-loss                                     -0.017898
# incident_date                                    -0.023308
# incident_type                                     0.049501
# collision_type                                    0.005185
# incident_severity                                 0.012116
# authorities_contacted                             0.026088
# incident_state                                   -0.022310
# incident_city                                    -0.042366
# incident_hour_of_the_day                          0.075683
# number_of_vehicles_involved                       0.045981
# property_damage                                  -0.002839
# bodily_injuries                                   0.000698
# witnesses                                         0.067651
# police_report_available                           0.027967
# total_claim_amount                               -0.017874
# injury_claim                                     -0.005370
# property_claim                                   -0.015862
# vehicle_claim                                    -0.018447
# auto_make                                        -0.009452
# auto_model                                        0.053055
# auto_year                                         0.018915
# fraud_reported                                   -0.000134
# months_bw_incident_and_bind                      -0.513638
# incident_within_customership                      1.000000
#
# [39 rows x 39 columns]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),cmap="PuBu",vmin=-1,vmax=1,annot=True,linewidth=1)
plt.show()

# %%
df=df.drop("vehicle_claim",axis=1)

# %%
df = df.drop(['policy_bind_date', 'incident_date'], axis = 1)

# %%
x=df.drop("fraud_reported",axis=1)

# %%
y=df["fraud_reported"]

# %%
y
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: fraud_reported, Length: 998, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(x,y)
print(model.feature_importances_)
# Out:
# [0.02872327 0.02895955 0.02370892 0.02161145 0.02286804 0.02696917
#  0.01760223 0.02846195 0.01787095 0.02583025 0.02799732 0.04015909
#  0.02618487 0.02396917 0.0239393  0.01750742 0.02175987 0.15796814
#  0.02709363 0.02848089 0.02634312 0.02776336 0.01575677 0.01800823
#  0.02222039 0.0236469  0.01543219 0.03060682 0.02799018 0.02919163
#  0.02860057 0.02661933 0.02747795 0.02550749 0.0171696 ]

# %%
df.shape
# Out:
# (998, 36)

# %%
#Finding 10 most important features
feature_importances = pd.Series(model.feature_importances_, index = x.columns)
feature_importances.nlargest(10).plot(kind = 'barh')
plt.show()

# %%
df.shape
# Out:
# (998, 36)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 998 entries, 0 to 999
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   months_as_customer            998 non-null    int64
#  1   age                           998 non-null    int64
#  2   policy_state                  998 non-null    int64
#  3   policy_csl                    998 non-null    int64
#  4   policy_deductable             998 non-null    int64
#  5   policy_annual_premium         998 non-null    float64
#  6   umbrella_limit                998 non-null    float64
#  7   insured_zip                   998 non-null    int64
#  8   insured_sex                   998 non-null    int64
#  9   insured_education_level       998 non-null    int64
#  10  insured_occupation            998 non-null    int64
#  11  insured_hobbies               998 non-null    int64
#  12  insured_relationship          998 non-null    int64
#  13  capital-gains                 998 non-null    int64
#  14  capital-loss                  998 non-null    int64
#  15  incident_type                 998 non-null    int64
#  16  collision_type                998 non-null    int64
#  17  incident_severity             998 non-null    int64
#  18  authorities_contacted         998 non-null    int64
#  19  incident_state                998 non-null    int64
#  20  incident_city                 998 non-null    int64
#  21  incident_hour_of_the_day      998 non-null    int64
#  22  number_of_vehicles_involved   998 non-null    int64
#  23  property_damage               998 non-null    int64
#  24  bodily_injuries               998 non-null    int64
#  25  witnesses                     998 non-null    int64
#  26  police_report_available       998 non-null    int64
#  27  total_claim_amount            998 non-null    int64
#  28  injury_claim                  998 non-null    int64
#  29  property_claim                998 non-null    float64
#  30  auto_make                     998 non-null    int64
#  31  auto_model                    998 non-null    int64
#  32  auto_year                     998 non-null    int64
#  33  fraud_reported                998 non-null    int64
#  34  months_bw_incident_and_bind   998 non-null    float64
#  35  incident_within_customership  998 non-null    int64
# dtypes: float64(4), int64(32)
# memory usage: 288.5 KB

# %%
#Finding 10 least important features
feature_importances.nsmallest(10).plot(kind = 'barh')
plt.show()

# %%
df=df.drop(['property_damage','umbrella_limit','number_of_vehicles_involved','incident_within_customership','police_report_available','insured_sex','incident_type'],axis=1)

# %%
df.shape
# Out:
# (998, 29)

# %%
df
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             0           0               1000
# 1                   228   42             1           0               2000
# 2                   134   29             0           1               2000
# 3                   256   41             2           0               2000
# 4                   228   44             2           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             0           2               1000
# 996                 285   41             2           1               1000
# 997                 130   34             0           0                500
# 998                 458   62             2           2               2000
# 999                 456   60             0           0               1000
#
#      policy_annual_premium  insured_zip  insured_education_level  \
# 0                  1406.91       466132                        0
# 1                  1197.22       468176                        0
# 2                  1413.14       430632                        1
# 3                  1415.74       608117                        1
# 4                  1583.91       610706                        2
# ..                     ...          ...                      ...
# 995                1310.80       431289                        3
# 996                1436.79       608177                        1
# 997                1383.49       442797                        3
# 998                1356.92       441714                        2
# 999                 766.19       612260                        2
#
#      insured_occupation  insured_hobbies  ...  bodily_injuries  witnesses  \
# 0                     0                0  ...                1          2
# 1                     1                1  ...                0          0
# 2                     2                2  ...                2          3
# 3                     3                2  ...                1          2
# 4                     2                2  ...                0          1
# ..                  ...              ...  ...              ...        ...
# 995                   0               12  ...                0          1
# 996                   5                0  ...                2          3
# 997                   3                3  ...                2          3
# 998                  11                4  ...                0          1
# 999                   2               14  ...                0          3
#
#      total_claim_amount  injury_claim  property_claim  auto_make  auto_model  \
# 0                 71610          6510         13020.0          0           0
# 1                  5070           780           780.0          1           1
# 2                 34650          7700          3850.0          2           2
# 3                 63400          6340          6340.0          3           3
# 4                  6500          1300           650.0          4           4
# ..                  ...           ...             ...        ...         ...
# 995               87200         17440          8720.0         12          31
# 996              108480         18080         18080.0         13          27
# 997               67500          7500          7500.0          9          17
# 998               46980          5220          5220.0          6           7
# 999                5060           460           920.0          1           1
#
#      auto_year  fraud_reported  months_bw_incident_and_bind
# 0         2004               0                     3.333333
# 1         2007               0                   104.333333
# 2         2007               1                   176.066667
# 3         2014               0                   299.866667
# 4         2009               1                     8.533333
# ..         ...             ...                          ...
# 995       2006               1                   287.400000
# 996       2015               1                    12.800000
# 997       1996               1                   145.266667
# 998       1998               1                    39.866667
# 999       2007               1                   222.700000
#
# [998 rows x 29 columns]

# %%
print(mappings['fraud_reported'])
# Out:
# {'Y': 0, 'N': 1}

# %%
print("YES:" ,y[y==0].shape[0])
print("NO:" ,y[y==1].shape[0])
# Out:
# YES: 247
# NO: 751

# %%
for i in dict(feature_importances.nlargest(10)):
 if i in mappings:
  chart=pd.crosstab(index=df[i],columns=df['fraud_reported'])
  print('fraud_reported'+':',mappings['fraud_reported'])
  print(i+':',mappings[i])
  print(chart)
  print()
  chart.plot.bar()
# Out:
# fraud_reported: {'Y': 0, 'N': 1}
# incident_severity: {'Major Damage': 0, 'Minor Damage': 1, 'Total Loss': 2, 'Trivial Damage': 3}
# fraud_reported       0    1
# incident_severity
# 0                  167  108
# 1                   38  316
# 2                   36  243
# 3                    6   84
#
# fraud_reported: {'Y': 0, 'N': 1}
# insured_hobbies: {'sleeping': 0, 'reading': 1, 'board-games': 2, 'bungie-jumping': 3, 'base-jumping': 4, 'golf': 5, 'camping': 6, 'dancing': 7, 'skydiving': 8, 'movies': 9, 'hiking': 10, 'yachting': 11, 'paintball': 12, 'chess': 13, 'kayaking': 14, 'polo': 15, 'basketball': 16, 'video-games': 17, 'cross-fit': 18, 'exercise': 19}
# fraud_reported    0   1
# insured_hobbies
# 0                 8  33
# 1                17  47
# 2                14  34
# 3                 9  47
# 4                13  36
# 5                 6  49
# 6                 5  50
# 7                 5  38
# 8                11  38
# 9                 9  46
# 10               12  40
# 11               16  37
# 12               13  44
# 13               38   8
# 14                5  48
# 15               13  33
# 16                6  28
# 17               10  40
# 18               26   9
# 19               11  46
#
# fraud_reported: {'Y': 0, 'N': 1}
# auto_make: {'Saab': 0, 'Mercedes': 1, 'Dodge': 2, 'Chevrolet': 3, 'Accura': 4, 'Nissan': 5, 'Audi': 6, 'Toyota': 7, 'Ford': 8, 'Suburu': 9, 'BMW': 10, 'Jeep': 11, 'Honda': 12, 'Volkswagen': 13}
# fraud_reported   0   1
# auto_make
# 0               18  62
# 1               22  43
# 2               20  60
# 3               21  54
# 4               13  55
# 5               14  64
# 6               21  48
# 7               13  56
# 8               22  50
# 9               19  61
# 10              20  52
# 11              11  56
# 12              14  41
# 13              19  49
#
# fraud_reported: {'Y': 0, 'N': 1}
# incident_state: {'SC': 0, 'VA': 1, 'NY': 2, 'OH': 3, 'WV': 4, 'NC': 5, 'PA': 6}
# fraud_reported   0    1
# incident_state
# 0               73  175
# 1               25   85
# 2               58  204
# 3               10   13
# 4               39  177
# 5               34   75
# 6                8   22
#
# fraud_reported: {'Y': 0, 'N': 1}
# insured_occupation: {'craft-repair': 0, 'machine-op-inspct': 1, 'sales': 2, 'armed-forces': 3, 'tech-support': 4, 'prof-specialty': 5, 'other-service': 6, 'priv-house-serv': 7, 'exec-managerial': 8, 'protective-serv': 9, 'transport-moving': 10, 'handlers-cleaners': 11, 'adm-clerical': 12, 'farming-fishing': 13}
# fraud_reported       0   1
# insured_occupation
# 0                   22  52
# 1                   22  69
# 2                   21  55
# 3                   17  52
# 4                   22  56
# 5                   18  67
# 6                   12  59
# 7                   12  59
# 8                   28  48
# 9                   14  49
# 10                  21  51
# 11                  11  43
# 12                  11  54
# 13                  16  37

# %%
for i in dict(feature_importances.nlargest(10)):
 if i not in mappings:
  df_specific_column=df.pivot(columns='fraud_reported',values=i)
  df_specific_column.plot.density(figsize=(7,7),linewidth=4)
  plt.xlabel(i)

# %%
df
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             0           0               1000
# 1                   228   42             1           0               2000
# 2                   134   29             0           1               2000
# 3                   256   41             2           0               2000
# 4                   228   44             2           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             0           2               1000
# 996                 285   41             2           1               1000
# 997                 130   34             0           0                500
# 998                 458   62             2           2               2000
# 999                 456   60             0           0               1000
#
#      policy_annual_premium  insured_zip  insured_education_level  \
# 0                  1406.91       466132                        0
# 1                  1197.22       468176                        0
# 2                  1413.14       430632                        1
# 3                  1415.74       608117                        1
# 4                  1583.91       610706                        2
# ..                     ...          ...                      ...
# 995                1310.80       431289                        3
# 996                1436.79       608177                        1
# 997                1383.49       442797                        3
# 998                1356.92       441714                        2
# 999                 766.19       612260                        2
#
#      insured_occupation  insured_hobbies  ...  bodily_injuries  witnesses  \
# 0                     0                0  ...                1          2
# 1                     1                1  ...                0          0
# 2                     2                2  ...                2          3
# 3                     3                2  ...                1          2
# 4                     2                2  ...                0          1
# ..                  ...              ...  ...              ...        ...
# 995                   0               12  ...                0          1
# 996                   5                0  ...                2          3
# 997                   3                3  ...                2          3
# 998                  11                4  ...                0          1
# 999                   2               14  ...                0          3
#
#      total_claim_amount  injury_claim  property_claim  auto_make  auto_model  \
# 0                 71610          6510         13020.0          0           0
# 1                  5070           780           780.0          1           1
# 2                 34650          7700          3850.0          2           2
# 3                 63400          6340          6340.0          3           3
# 4                  6500          1300           650.0          4           4
# ..                  ...           ...             ...        ...         ...
# 995               87200         17440          8720.0         12          31
# 996              108480         18080         18080.0         13          27
# 997               67500          7500          7500.0          9          17
# 998               46980          5220          5220.0          6           7
# 999                5060           460           920.0          1           1
#
#      auto_year  fraud_reported  months_bw_incident_and_bind
# 0         2004               0                     3.333333
# 1         2007               0                   104.333333
# 2         2007               1                   176.066667
# 3         2014               0                   299.866667
# 4         2009               1                     8.533333
# ..         ...             ...                          ...
# 995       2006               1                   287.400000
# 996       2015               1                    12.800000
# 997       1996               1                   145.266667
# 998       1998               1                    39.866667
# 999       2007               1                   222.700000
#
# [998 rows x 29 columns]

# %%
from sklearn.model_selection import train_test_split
y = df['fraud_reported']
x = df.drop('fraud_reported', axis = 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 745                 258   41             2           1                500
# 286                 163   31             1           1               1000
# 165                 108   29             1           2               1000
# 961                 128   35             1           0               1000
# 494                 338   47             0           0               2000
# ..                  ...  ...           ...         ...                ...
# 106                 464   61             0           2               1000
# 270                 369   55             0           0               2000
# 862                 299   44             0           2               1000
# 436                  61   23             2           1                500
# 102                 279   41             2           0                500
#
#      policy_annual_premium  insured_zip  insured_education_level  \
# 745                1042.25       601206                        3
# 286                1004.63       460359                        6
# 165                1337.92       441536                        1
# 961                1074.99       453620                        2
# 494                1486.04       615688                        2
# ..                     ...          ...                      ...
# 106                1125.37       604450                        2
# 270                1589.54       444734                        5
# 862                1653.32       460517                        5
# 436                1111.72       448857                        6
# 102                1497.35       460742                        6
#
#      insured_occupation  insured_hobbies  ...  incident_hour_of_the_day  \
# 745                   8                1  ...                         0
# 286                   7               10  ...                        14
# 165                   3                3  ...                         4
# 961                  12                3  ...                        16
# 494                   3                2  ...                         1
# ..                  ...              ...  ...                       ...
# 106                   5               16  ...                         6
# 270                  11                6  ...                         6
# 862                   6                3  ...                         3
# 436                   8                3  ...                         6
# 102                   5                3  ...                        16
#
#      bodily_injuries  witnesses  total_claim_amount  injury_claim  \
# 745                2          3               81240          6770
# 286                2          0               63910          5810
# 165                2          2               61380         11160
# 961                2          0                7590          1380
# 494                2          3               64100         12820
# ..               ...        ...                 ...           ...
# 106                0          2               79800          6650
# 270                2          0               85300         17060
# 862                2          0               54240          6780
# 436                1          2               41850          4650
# 102                2          3               28800             0
#
#      property_claim  auto_make  auto_model  auto_year  \
# 745         20310.0          1          22       2008
# 286         11620.0          9          18       1999
# 165          5580.0          9          15       2012
# 961           690.0          4          13       2012
# 494          6410.0          2           2       2014
# ..              ...        ...         ...        ...
# 106         19950.0          0           5       2000
# 270          8530.0          7          11       2003
# 862          6780.0          9          17       2009
# 436          4650.0          9          15       1997
# 102          3600.0          8          34       2013
#
#      months_bw_incident_and_bind
# 745                   170.200000
# 286                   155.466667
# 165                    87.933333
# 961                   167.400000
# 494                    84.866667
# ..                           ...
# 106                   295.466667
# 270                    21.733333
# 862                    75.666667
# 436                    97.000000
# 102                   166.166667
#
# [798 rows x 28 columns]

# %%
y_train
# Out:
# 745    0
# 286    1
# 165    1
# 961    1
# 494    0
#       ..
# 106    0
# 270    1
# 862    1
# 436    1
# 102    1
# Name: fraud_reported, Length: 798, dtype: int64

# %%
x_test
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 454                 126   30             2           0               2000
# 794                 320   48             2           0               2000
# 209                 404   53             1           0                500
# 310                 253   41             0           1               2000
# 741                 100   33             0           0                500
# ..                  ...  ...           ...         ...                ...
# 78                  194   39             0           2               1000
# 29                  241   45             2           2               2000
# 277                 264   41             0           1                500
# 261                 156   31             2           1               2000
# 424                 150   31             1           2               1000
#
#      policy_annual_premium  insured_zip  insured_education_level  \
# 454                1171.75       472163                        2
# 794                1730.49       443342                        5
# 209                 767.14       466201                        2
# 310                1312.75       471453                        1
# 741                1124.59       459428                        5
# ..                     ...          ...                      ...
# 78                 1489.24       608335                        6
# 29                 1104.50       432211                        1
# 277                1411.30       474801                        1
# 261                1134.08       446895                        1
# 424                1354.50       456602                        3
#
#      insured_occupation  insured_hobbies  ...  incident_hour_of_the_day  \
# 454                   1                2  ...                        23
# 794                  10               10  ...                        13
# 209                   2                1  ...                         8
# 310                   2                7  ...                        10
# 741                  12                5  ...                         4
# ..                  ...              ...  ...                       ...
# 78                    6               14  ...                        15
# 29                    1               16  ...                         5
# 277                   5               18  ...                         4
# 261                   6                1  ...                         3
# 424                   1                4  ...                         6
#
#      bodily_injuries  witnesses  total_claim_amount  injury_claim  \
# 454                2          3               48730          4430
# 794                2          0               56160          4680
# 209                0          1                8800          1760
# 310                2          2               80740          7340
# 741                1          2               40800          6800
# ..               ...        ...                 ...           ...
# 78                 2          2                8060          1240
# 29                 2          2               91650         14100
# 277                1          0               60390         10980
# 261                2          0               59000          5900
# 424                0          3               64800          6480
#
#      property_claim  auto_make  auto_model  auto_year  \
# 454          4430.0          3          33       2011
# 794          9360.0          0           5       1995
# 209           880.0          9          15       2002
# 310         14680.0          7           8       2014
# 741          6800.0         10          25       2004
# ..              ...        ...         ...        ...
# 78           1240.0          0           5       2004
# 29          14100.0          4          16       2011
# 277          5490.0         10          24       2004
# 261          5900.0          8          34       2013
# 424         12960.0          9          18       2000
#
#      months_bw_incident_and_bind
# 454                    28.233333
# 794                    21.200000
# 209                     1.166667
# 310                    21.033333
# 741                   120.066667
# ..                           ...
# 78                     56.966667
# 29                     11.600000
# 277                   149.933333
# 261                   223.766667
# 424                   246.700000
#
# [200 rows x 28 columns]

# %%
y_test
# Out:
# 454    1
# 794    1
# 209    1
# 310    0
# 741    1
#       ..
# 78     1
# 29     1
# 277    0
# 261    0
# 424    0
# Name: fraud_reported, Length: 200, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
pred = model.predict(x_test)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
print(accuracy_score(y_test,pred))
# Out:
# [[  1  48]
#  [  0 151]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.04        49
#            1       0.76      1.00      0.86       151
#
#     accuracy                           0.76       200
#    macro avg       0.88      0.51      0.45       200
# weighted avg       0.82      0.76      0.66       200
#
# 0.76
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model = model.fit(x_train,y_train)
pred = model.predict(x_test)
print('Accuracy:', accuracy_score(y_test, pred))
print('\n classification report:\n',classification_report(y_test,pred))
print('\n confusion matrix:\n',confusion_matrix(y_test, pred))
# Out:
# Accuracy: 0.705
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.19      0.06      0.09        49
#            1       0.75      0.91      0.82       151
#
#     accuracy                           0.70       200
#    macro avg       0.47      0.49      0.46       200
# weighted avg       0.61      0.70      0.64       200
#
#
#  confusion matrix:
#  [[  3  46]
#  [ 13 138]]

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model = model.fit(x_train,y_train)
pred = model.predict(x_test)
print('Accuracy:', accuracy_score(y_test, pred))
print('\n classification report:\n',classification_report(y_test,pred))
print('\n confusion matrix:\n',confusion_matrix(y_test, pred))
# Out:
# Accuracy: 0.75
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.47      0.14      0.22        49
#            1       0.77      0.95      0.85       151
#
#     accuracy                           0.75       200
#    macro avg       0.62      0.54      0.53       200
# weighted avg       0.70      0.75      0.70       200
#
#
#  confusion matrix:
#  [[  7  42]
#  [  8 143]]

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model = model.fit(x_train,y_train)
pred = model.predict(x_test)
print('Accuracy:', accuracy_score(y_test, pred))
print('\n classification report:\n',classification_report(y_test,pred))
print('\n confusion matrix:\n',confusion_matrix(y_test, pred))
# Out:
# Accuracy: 0.73
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.45      0.43      0.44        49
#            1       0.82      0.83      0.82       151
#
#     accuracy                           0.73       200
#    macro avg       0.63      0.63      0.63       200
# weighted avg       0.73      0.73      0.73       200
#
#
#  confusion matrix:
#  [[ 21  28]
#  [ 26 125]]

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model = model.fit(x_train,y_train)
pred = model.predict(x_test)
print('Accuracy:', accuracy_score(y_test, pred))
print('\n classification report:\n',classification_report(y_test,pred))
print('\n confusion matrix:\n',confusion_matrix(y_test, pred))
# Out:
# Accuracy: 0.805
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.47      0.54        49
#            1       0.84      0.91      0.88       151
#
#     accuracy                           0.81       200
#    macro avg       0.74      0.69      0.71       200
# weighted avg       0.79      0.81      0.79       200
#
#
#  confusion matrix:
#  [[ 23  26]
#  [ 13 138]]

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model = model.fit(x_train,y_train)
pred = model.predict(x_test)
print('Accuracy:', accuracy_score(y_test, pred))
print('\n classification report:\n',classification_report(y_test,pred))
print('\n confusion matrix:\n',confusion_matrix(y_test, pred))
# Out:
# Accuracy: 0.83
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.63      0.65        49
#            1       0.88      0.89      0.89       151
#
#     accuracy                           0.83       200
#    macro avg       0.77      0.76      0.77       200
# weighted avg       0.83      0.83      0.83       200
#
#
#  confusion matrix:
#  [[ 31  18]
#  [ 16 135]]

# %% [markdown]
# ##Predictive Model Building##

# %%
##from sklearn.model_selection import GridSearchCV

#params = { 'max_depth': [3,6,10], 'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5], 'n_estimators': [100, 500, 1000], 'colsample_bytree': [0.3, 0.7, 1], 'subsample': [0.3, 0.7, 1]}
#xgbC = XGBClassifier()
#optimize_model = GridSearchCV(estimator = xgbC, param_grid = params, scoring='neg_mean_squared_error', verbose=1)
#optimize_model.fit(x, y)
#print("Best parameters: ", optimize_model.best_params_)

# %%
from xgboost import XGBClassifier

model = XGBClassifier(colsample_bytree = 1, learning_rate = 0.01, max_depth = 10, n_estimators = 500, subsample = 1)
model = model.fit(x_train,y_train)
pred = model.predict(x_test)

print('Accuracy:', accuracy_score(y_test, pred))
print('\n classification report:\n',classification_report(y_test,pred))
print('\n confusion matrix:\n',confusion_matrix(y_test, pred))
# Out:
# Accuracy: 0.805
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.61      0.61        49
#            1       0.87      0.87      0.87       151
#
#     accuracy                           0.81       200
#    macro avg       0.74      0.74      0.74       200
# weighted avg       0.81      0.81      0.81       200
#
#
#  confusion matrix:
#  [[ 30  19]
#  [ 20 131]]

# %%
pred_prob = model.predict_proba(x_test)[:, 1]

# %%
pred_prob
# Out:
# array([0.97580224, 0.91482604, 0.983445  , 0.18093097, 0.93982804,
#        0.9892804 , 0.9755504 , 0.9823048 , 0.12306674, 0.88883334,
#        0.986604  , 0.99470645, 0.9906724 , 0.9689772 , 0.9818425 ,
#        0.38376456, 0.9830784 , 0.90026355, 0.08506665, 0.9596516 ,
#        0.9862099 , 0.98971224, 0.48954734, 0.9641533 , 0.98479617,
#        0.7236251 , 0.9883333 , 0.13807312, 0.98378366, 0.9811399 ,
#        0.08689041, 0.46085843, 0.9646887 , 0.8997588 , 0.99126464,
#        0.9763223 , 0.98945403, 0.32570934, 0.93944365, 0.11680393,
#        0.9764449 , 0.97299564, 0.17620443, 0.16021223, 0.9757178 ,
#        0.24867864, 0.6873079 , 0.97214365, 0.987911  , 0.9923574 ,
#        0.9771995 , 0.99151707, 0.75449085, 0.3028101 , 0.5820005 ,
#        0.10250901, 0.990716  , 0.11359971, 0.45847434, 0.70786273,
#        0.8820632 , 0.6851979 , 0.47623634, 0.98621726, 0.7036621 ,
#        0.965389  , 0.953928  , 0.89093167, 0.9432741 , 0.8258236 ,
#        0.5643878 , 0.47502762, 0.45974955, 0.99040717, 0.93770975,
#        0.2859878 , 0.2574928 , 0.9763515 , 0.9701257 , 0.97658396,
#        0.94733095, 0.9487642 , 0.9655466 , 0.09114731, 0.9837347 ,
#        0.5171692 , 0.92236507, 0.2735582 , 0.97256416, 0.9935242 ,
#        0.91788006, 0.20908386, 0.98520327, 0.31255403, 0.6965486 ,
#        0.98105067, 0.51418674, 0.9898858 , 0.97617096, 0.9677796 ,
#        0.966169  , 0.9628859 , 0.98068583, 0.7486148 , 0.58355314,
#        0.9828514 , 0.83198124, 0.93321   , 0.88660467, 0.9236535 ,
#        0.361063  , 0.9795517 , 0.98555183, 0.9672841 , 0.31333938,
#        0.99166274, 0.99022186, 0.09112035, 0.9854897 , 0.9838959 ,
#        0.2652942 , 0.48745912, 0.9872896 , 0.9134718 , 0.9869196 ,
#        0.30249327, 0.96144205, 0.99063736, 0.6477824 , 0.9707948 ,
#        0.9723875 , 0.9869425 , 0.6742309 , 0.96820974, 0.9864768 ,
#        0.9917544 , 0.3581106 , 0.9746689 , 0.9866571 , 0.9809558 ,
#        0.74433887, 0.9406562 , 0.88978094, 0.9587536 , 0.4797326 ,
#        0.99024093, 0.8157519 , 0.9669239 , 0.33734134, 0.9745544 ,
#        0.990761  , 0.45330957, 0.9820655 , 0.9793521 , 0.95204973,
#        0.44630787, 0.9589037 , 0.95659757, 0.9847317 , 0.9607985 ,
#        0.12398595, 0.7336117 , 0.23896973, 0.06235105, 0.9880477 ,
#        0.97599787, 0.41352224, 0.96847165, 0.92571265, 0.9350582 ,
#        0.15354785, 0.977878  , 0.94437   , 0.9471947 , 0.40021393,
#        0.9927498 , 0.9836789 , 0.26626274, 0.9926001 , 0.31675893,
#        0.6805828 , 0.80692977, 0.9859158 , 0.98688614, 0.9831771 ,
#        0.95586115, 0.4771627 , 0.18400462, 0.9869261 , 0.9781762 ,
#        0.9424085 , 0.9089642 , 0.9655019 , 0.19705015, 0.98896   ,
#        0.96978843, 0.7647254 , 0.6582579 , 0.1698422 , 0.12181577],
#       dtype=float32)

# %%
pred_prob = model.predict_proba(x_test)[:, 1]

from sklearn import metrics
def plot_roc_curve(fpr, tpr):
  plt.plot(fpr, tpr, color='orange', label='ROC')
  plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('Receiver Operating Characteristic (ROC) Curve')
  plt.legend()
  plt.show()

# %%
y_true = y_test
y_scores = pred_prob
fpr, tpr, thresholds = metrics.roc_curve(y_true, y_scores)
print(tpr)
print(fpr)
print(thresholds)
# Out:
# [0.         0.00662252 0.18543046 0.18543046 0.29139073 0.29139073
#  0.36423841 0.36423841 0.60927152 0.60927152 0.64238411 0.64238411
#  0.8013245  0.8013245  0.82781457 0.82781457 0.83443709 0.83443709
#  0.8410596  0.8410596  0.84768212 0.84768212 0.86092715 0.86092715
#  0.86754967 0.86754967 0.87417219 0.87417219 0.88741722 0.88741722
#  0.90066225 0.90066225 0.91390728 0.91390728 0.9205298  0.9205298
#  0.93377483 0.93377483 0.94701987 0.94701987 0.95364238 0.95364238
#  0.98013245 0.98013245 0.99337748 0.99337748 1.        ]
# [0.         0.         0.         0.02040816 0.02040816 0.04081633
#  0.04081633 0.06122449 0.06122449 0.08163265 0.08163265 0.10204082
#  0.10204082 0.14285714 0.14285714 0.16326531 0.16326531 0.18367347
#  0.18367347 0.2244898  0.2244898  0.34693878 0.34693878 0.36734694
#  0.36734694 0.42857143 0.42857143 0.44897959 0.44897959 0.48979592
#  0.48979592 0.51020408 0.51020408 0.53061224 0.53061224 0.55102041
#  0.55102041 0.65306122 0.65306122 0.75510204 0.75510204 0.85714286
#  0.85714286 0.89795918 0.89795918 1.         1.        ]
# [       inf 0.99470645 0.9869196  0.98688614 0.983445   0.9831771
#  0.9793521  0.9781762  0.9589037  0.9587536  0.9487642  0.94733095
#  0.8820632  0.8258236  0.75449085 0.7486148  0.74433887 0.7336117
#  0.7236251  0.7036621  0.6965486  0.6477824  0.5820005  0.5643878
#  0.5171692  0.48745912 0.4797326  0.4771627  0.47502762 0.45974955
#  0.45330957 0.44630787 0.40021393 0.38376456 0.361063   0.3581106
#  0.32570934 0.30249327 0.2735582  0.23896973 0.20908386 0.1698422
#  0.12398595 0.12181577 0.11359971 0.08506665 0.06235105]

# %%
print(metrics.roc_auc_score(y_true, y_scores))
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print(optimal_threshold)
plot_roc_curve(fpr, tpr)
# Out:
# 0.8586295445330451
# 0.8820632

# %%
pred = 1*(pred_prob >= optimal_threshold)

print('Accuracy:' , accuracy_score(y_test, pred))
print('\n classification report:\n', classification_report(y_test, pred))
print('\n confusion matrix:\n', confusion_matrix(y_test,pred))
# Out:
# Accuracy: 0.825
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.90      0.72        49
#            1       0.96      0.80      0.87       151
#
#     accuracy                           0.82       200
#    macro avg       0.78      0.85      0.79       200
# weighted avg       0.87      0.82      0.83       200
#
#
#  confusion matrix:
#  [[ 44   5]
#  [ 30 121]]
